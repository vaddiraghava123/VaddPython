# %% [markdown]
# #Open CV
#  - Image and Video
#  - Given picture or video any flaws (lopalu) are there
#  - I will make a better quality, every one able to understand even my AI machines can transform those make good conclusion

# %% [markdown]
# # Tech Stack
# - Programming - Python
#
# - Package - OpenCV
#
# - Platform - Google colab

# %% [markdown]
# # Install Packages

# %%
pip install opencv-python

# %%
import cv2
from  google.colab.patches import cv2_imshow

# %% [markdown]
# # Load or read the image

# %%
cv2_imshow(cv2.imread('/content/IMG_20230101_171553 (1).jpg'))

# img_read = cv2.imread('image.jpg')
# cv2_imshow(img_read)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Image Types
#
# - Gray / Black & white
#
# - Color
#
# - '0' indicates - Black
#
# - '1' indicates - White
#
# - Color Image Channel
#
#   - RGB [ Red, Green, Blue ]

# %%
img_cv = cv2.imread('/content/IMG_20230101_171553 (1).jpg')
img_cv
# Out:
# array([[[112, 117, 118],
#         [111, 116, 117],
#         [117, 122, 123],
#         ...,
#         [156, 168, 172],
#         [156, 168, 172],
#         [156, 168, 172]],
#
#        [[109, 114, 115],
#         [110, 115, 116],
#         [118, 123, 124],
#         ...,
#         [156, 168, 172],
#         [156, 168, 172],
#         [156, 168, 172]],
#
#        [[106, 111, 112],
#         [109, 114, 115],
#         [118, 123, 124],
#         ...,
#         [156, 168, 172],
#         [156, 168, 172],
#         [156, 168, 172]],
#
#        ...,
#
#        [[118, 126, 149],
#         [113, 121, 144],
#         [119, 127, 150],
#         ...,
#         [ 64,  74,  91],
#         [ 64,  74,  91],
#         [ 64,  74,  91]],
#
#        [[115, 124, 144],
#         [106, 115, 135],
#         [118, 127, 147],
#         ...,
#         [ 64,  74,  91],
#         [ 64,  74,  91],
#         [ 64,  74,  91]],
#
#        [[119, 128, 148],
#         [105, 114, 134],
#         [120, 129, 149],
# ...

# %%
img_cv.shape # Matrix (rows, columns, color channel [RGB])

# if its black and white there is no color channel [ rows, columns]
# Out:
# (4608, 2068, 3)

# %%
cv2.split(img_cv )
# Out:
# (array([[112, 111, 117, ..., 156, 156, 156],
#         [109, 110, 118, ..., 156, 156, 156],
#         [106, 109, 118, ..., 156, 156, 156],
#         ...,
#         [118, 113, 119, ...,  64,  64,  64],
#         [115, 106, 118, ...,  64,  64,  64],
#         [119, 105, 120, ...,  64,  64,  64]], dtype=uint8),
#  array([[117, 116, 122, ..., 168, 168, 168],
#         [114, 115, 123, ..., 168, 168, 168],
#         [111, 114, 123, ..., 168, 168, 168],
#         ...,
#         [126, 121, 127, ...,  74,  74,  74],
#         [124, 115, 127, ...,  74,  74,  74],
#         [128, 114, 129, ...,  74,  74,  74]], dtype=uint8),
#  array([[118, 117, 123, ..., 172, 172, 172],
#         [115, 116, 124, ..., 172, 172, 172],
#         [112, 115, 124, ..., 172, 172, 172],
#         ...,
#         [149, 144, 150, ...,  91,  91,  91],
#         [144, 135, 147, ...,  91,  91,  91],
#         [148, 134, 149, ...,  91,  91,  91]], dtype=uint8))

# %%
b, g, r = cv2.split(img_cv )
b, g, r
# Out:
# (array([[112, 111, 117, ..., 156, 156, 156],
#         [109, 110, 118, ..., 156, 156, 156],
#         [106, 109, 118, ..., 156, 156, 156],
#         ...,
#         [118, 113, 119, ...,  64,  64,  64],
#         [115, 106, 118, ...,  64,  64,  64],
#         [119, 105, 120, ...,  64,  64,  64]], dtype=uint8),
#  array([[117, 116, 122, ..., 168, 168, 168],
#         [114, 115, 123, ..., 168, 168, 168],
#         [111, 114, 123, ..., 168, 168, 168],
#         ...,
#         [126, 121, 127, ...,  74,  74,  74],
#         [124, 115, 127, ...,  74,  74,  74],
#         [128, 114, 129, ...,  74,  74,  74]], dtype=uint8),
#  array([[118, 117, 123, ..., 172, 172, 172],
#         [115, 116, 124, ..., 172, 172, 172],
#         [112, 115, 124, ..., 172, 172, 172],
#         ...,
#         [149, 144, 150, ...,  91,  91,  91],
#         [144, 135, 147, ...,  91,  91,  91],
#         [148, 134, 149, ...,  91,  91,  91]], dtype=uint8))

# %%
cv2_imshow(b)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
cv2_imshow(g)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import matplotlib.pyplot as plt
plt.imshow(g, cmap = 'gray')

# %%
import matplotlib.pyplot as plt
plt.imshow(r, cmap = 'Reds')

# %% [markdown]
# # Entire Code

# %%
# install package
# pip install opencv-python

import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# load or read the image
img_cv = cv2.imread('/content/IMG_20230101_171553 (1).jpg')
img_cv

cv2_imshow(img_cv)

b, g, r = cv2.split(img_cv )
b, g, r

cv2_imshow(b)

cv2_imshow(g)

cv2_imshow(r)

## Display image using matplotlib

plt.imshow(g, cmap = 'gray')

plt.imshow(r, cmap = 'Reds')

plt.imshow(b, cmpa = 'black')
# Out:
# Output hidden; open in https://colab.research.google.com to view.
