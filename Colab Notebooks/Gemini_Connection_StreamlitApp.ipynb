# %% [markdown]
# # Google Gemin connection with Python

# %%
pip install google-generativeai

# %%
import os
import google.generativeai as genai

api_key = "AIzaSyCqXNppjN4pn4ouy_LWHDYdbXXvpv7NBac"
genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# ...

# %%
model = genai.GenerativeModel("gemini-1.5-pro")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
rsp = model.generate_content("List of top 5 Indian crickers")

print(rsp.text)
# Out:
# Choosing a "top 5" is inherently subjective and depends on the criteria used (e.g., batting average, bowling strike rate, impact on the game, all-around ability, etc.).  There's no single definitive list.  However, here are 5 Indian cricketers frequently cited as among the best, spanning different eras and skillsets:
#
# 1. **Sachin Tendulkar:**  Widely regarded as one of the greatest batsmen of all time.  His prolific run-scoring across all formats and longevity make him a strong contender for any "best of" list.
#
# 2. **Virat Kohli:** A modern-day batting giant, known for his aggressive style, consistency, and exceptional chasing abilities.
#
# 3. **Kapil Dev:**  India's first World Cup-winning captain, a brilliant all-rounder, and a fast-bowling pioneer in India.
#
# 4. **Sunil Gavaskar:**  One of the finest opening batsmen, particularly renowned for his skill against fast bowling in an era preceding helmets.
#
# ...

# %%
import os
import google.generativeai as genai

api_key = "AIzaSyCqXNppjN4pn4ouy_LWHDYdbXXvpv7NBac"
genai.configure(api_key=api_key)

model = genai.GenerativeModel("gemini-1.5-pro")

rsp = model.generate_content("List of top 5 Indian crickers")

print(rsp.text)

# %% [markdown]
# # Image Model

# %% [markdown]
# Package name : Pillow for Image Model

# %%
from PIL import Image

# %%
img = Image.open("/content/06Feb.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=897x800>

# %%
import os
import google.generativeai as genai

api_key = "AIzaSyCqXNppjN4pn4ouy_LWHDYdbXXvpv7NBac"
genai.configure(api_key=api_key)

model = genai.GenerativeModel("gemini-1.5-flash")
prompt ="What are the objects and sizes and color"

response = model.generate_content([prompt,img])

print(response.text)
# Out:
# Here's a description of the objects, their approximate sizes (relative to each other), and color:
#
# **Color:** All objects are light pink/rose.
#
# **Objects and Sizes (relative):**
#
# * **Oval:** A small, vertically oriented oval.
# * **Rectangle:** A medium-sized rectangle, horizontally oriented. It's the largest of the simple shapes.
# * **Square:** A medium-sized square.  Similar in size to the rectangle.
# * **Triangle:** A medium-sized upward-pointing triangle. Similar in size to the square and rectangle.
# * **Arrow (Right):** A small, right-pointing arrow.
# * **Arrow (Left):** A small, left-pointing arrow.  Same size as the right arrow.
# * **Arrow (Down):** A small, downward-pointing arrow. Same size as the other arrows.
# * **Arrow (Up):** A small, upward-pointing arrow. Same size as the other arrows.
# * **Rhombus/Diamond:** A medium-sized rhombus (diamond shape).  Comparable in size to the square/triangle.
# ...

# %% [markdown]
# # Create application using streamlit

# %%
# !pip install streamlit
# !npm install localtunel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 49.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.6 MB/s eta 0:00:00
# ...
# ⠙⠹⠸⠼⠴⠦npm error code E404
# ⠧npm error 404 Not Found - GET https://registry.npmjs.org/localtunel - Not found
# ⠧npm error 404
# ⠧npm error 404  'localtunel@*' is not in this registry.
# ⠧npm error 404
# ⠧npm error 404 Note that you can also install from a
# ⠧npm error 404 tarball, folder, http url, or git url.
# ⠧npm error A complete log of this run can be found in: /root/.npm/_logs/2025-02-26T08_12_13_816Z-debug-0.log
# ⠧

# %%
# %%writefile ImageAnalytics_GoogleGemin.py
import streamlit as st
import google.generativeai as genai
from PIL import Image

api_key ="AIzaSyCqXNppjN4pn4ouy_LWHDYdbXXvpv7NBac"
genai.configure(api_key=api_key)

st.title("Image - analytics , Google Gemin Connection with Python")

uploaded_file = st.file_uploader("Upload Image", type =["png","jpg","jpeg"])
if uploaded_file is not None:
  img = Image.open(uploaded_file)
  st.image(img,caption="Uploaded Image")


prompt = st.text_input("Enter the text ")

if st.button("GET RESPONSE"):
  img = Image.open(uploaded_file)
  model = genai.GenerativeModel("gemini-1.5-flash")
  response = model.generate_content([prompt,img])
  st.markdown(response.text)
# Out:
# Writing ImageAnalytics_GoogleGemin.py

# %% [markdown]
# # Run streamlit application

# %% [markdown]
# Streamlit run on public URL ... Password is 34.124.174.211

# %%
# !streamlit run /content/ImageAnalytics_GoogleGemin.py & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.124.174.211
# ⠙
# ...
#
# ⠹⠸⠼⠴⠦
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.124.174.211:8501
#
# ⠧your url is: https://spicy-times-join.loca.lt
#   Stopping...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740564981.824012    2268 init.cc:232] grpc_wait_for_shutdown_with_timeout() timed out.

# %% [markdown]
# # Run streamlit application in local

# %%
# !streamlit run /content/ImageAnalytics_GoogleGemin.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.124.174.211:8501
