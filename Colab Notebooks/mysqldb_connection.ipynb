# %%
pip install mysql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 2.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.7-cp311-cp311-linux_x86_64.whl size=127566 sha256=1af8bcbf0eba9448b37b5fb830eab3024e3cbbcf7451acecbb82e3cb3f86c05a
#   Stored in directory: /root/.cache/pip/wheels/cd/5f/fb/dbe9e6e7e1e24f9e73164c77b5fdc19bd36240425835c0e635
# Successfully built mysqlclient
# ...

# %%
pip install ngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 26.4 MB/s eta 0:00:00
# ...

# %%
# prompt: ngrok tcp 3306 connect

# !pip install mysql-connector-python
# !pip install pyngrok

from pyngrok import ngrok
import mysql.connector

# Replace with your MySQL credentials
mysql_user = "root"
mysql_password = "Raghava123*"
mysql_database = "mysqldemo"

ngrok.set_auth_token("2wDw2HiOT1L6jaCsZHhlk3eRauu_6g3KpQA3yaAjwk9JRGV4Z")


# Open an HTTP tunnel to your local MySQL server
public_url = ngrok.connect(3306, "tcp")
print("Public URL:", public_url)

# Extract the public URL's host and port
public_host = public_url.public_url.split(":")[1][2:] # Remove 'tcp://' prefix
public_port = public_url.public_url.split(":")[2]

# Try to connect to the MySQL server using the public URL
try:
    mydb = mysql.connector.connect(
      host=public_host,
      port=public_port,
      user=mysql_user,
      password=mysql_password,
      database=mysql_database
    )

    print("Connection successful!")

    # Perform your MySQL operations here...
    # Example:
    mycursor = mydb.cursor()
    mycursor.execute("SELECT VERSION()")
    myresult = mycursor.fetchone()
    print(f"Database version: {myresult[0]}")

except mysql.connector.Error as err:
    print(f"Error connecting to MySQL: {err}")

finally:
    # Close the ngrok tunnel
    ngrok.disconnect(public_url)
    print("Ngrok tunnel closed.")
# Out:
# ...
# WARNING:pyngrok.process.ngrok:t=2025-04-27T09:05:40+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=71f34932b62db27a err="failed to start tunnel: You must add a credit or debit card before you can use TCP endpoints on a free account. We require a valid card as a way to combat abuse and keep the internet a safe place. This card will NOT  be charged.\nAdd a card to your account here: https://dashboard.ngrok.com/settings#id-verification\r\n\r\nERR_NGROK_8013\r\n"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     555     try:
# --> 556         response = urlopen(request, encoded_data, timeout)
#     557         response_data = response.read().decode("utf-8")
#
# ...

# %%
import MySQLdb as mysql

# Change the host to 'localhost' or the actual hostname or IP address of your MySQL server
mydb = mysql.connect(
  host="127.0.0.1",  # Updated host
  user="root",
  password="Raghava123*",
  database="mysqldemo",
  port = 3306
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM product")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
