# %% [markdown]
# # Entire code

# %%
# import packages
import google.generativeai as genai

api_key ="API_KEY"
genai.configure(api_key=api_key)

# Retreive list of models
for models in genai.list_models():
  print("Models are:: ", m.name)

# select model and prompt
model = genai.GenerativeModel('gemini-1.5-pro')
chat = model.start_chat(history=[]) #Model start chat, save history

# Simple prompt with out chat history
response = model.generate_content("Indian mens cricket team captian history")
print(response.text)

# Prompts with chat history
while True:
  qn = input("Enter a question :")
  if qn!="Exit":
    response = model.generate_content(qn)
    print(response.text)
  else:
    break

# %%
import google.generativeai as genai

api_key ="AIzaSyDxHxJKSHzfK1IdDcCS9dHQC3waYHuYPQg"
genai.configure(api_key=api_key)

for m in genai.list_models():
    print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model = genai.GenerativeModel('gemini-1.5-pro')
response = model.generate_content("Indian mens cricket team captian history")
print(response.text)
# Out:
# ## Indian Men's Cricket Team Captain History
#
# Here's a breakdown of the Indian men's cricket team captaincy history, focusing on Test, ODI, and T20I formats:
#
# **Test Cricket Captains:**
#
# * **1932-1934:** C.K. Nayudu (First official Test captain)
# * **1936-1952:** Various captains (including Vijay Hazare, Lala Amarnath, and Vijay Merchant)
# * **1952-1960:** Polly Umrigar
# * **1960-1962:** Nari Contractor
# * **1962-1964:** Mansoor Ali Khan Pataudi (First stint)
# * **1964-1967:** Various captains
# * **1967-1971:** Mansoor Ali Khan Pataudi (Second stint)
# * **1971-1975:** Ajit Wadekar (Led India to first-ever series victories against England and West Indies)
# * **1975-1979:** Bishen Singh Bedi
# * **1979-1980:** Sunil Gavaskar (First stint)
# * **1980-1981:** Gundappa Viswanath
# * **1981-1985:** Sunil Gavaskar (Second stint)
# * **1985-1989:** Kapil Dev (Led India to victory at the 1983 World Cup)
# * **1989-1990:** Kris Srikkanth
# * **1990-1996:** Mohammad Azharuddin
# ...

# %%
model = genai.GenerativeModel('gemini-1.5-pro')
chat = model.start_chat(history=[])
response = model.generate_content("Rohit Sharma total centuries in ODI")
response.text
# Out:
# 'Rohit Sharma has scored **30** centuries in One Day Internationals (ODIs) as of my last update. \n\nPlease note that sports statistics change frequently.  To get the most up-to-date information, I recommend checking a reliable sports website like ESPNcricinfo or similar. \n'

# %%
response = model.generate_content("Rohit Sharma total centuries in TEST")
response.text
# Out:
# 'Rohit Sharma, as of today, October 26, 2023, has scored **8** centuries in Test cricket. \n'

# %%
response = model.generate_content("Rohit Sharma  is  total centuries in TEST")
response.text
# Out:
# "I do not have access to real-time information, including rapidly changing sports statistics. \n\nTo find the most up-to-date number of Rohit Sharma's centuries in Test cricket, I recommend checking a reliable sports website like:\n\n* **ESPNcricinfo:** [https://www.espncricinfo.com/](https://www.espncricinfo.com/)\n* **Cricbuzz:** [https://www.cricbuzz.com/](https://www.cricbuzz.com/)\n\nThese websites will have the latest details on his career statistics. \n"

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
chat = model.start_chat(history=[]) #Model start chat, save history
while True:
  qn = input("Enter a question :")
  if qn!="Exit":
    response = model.generate_content(qn)
    print(response.text)
  else:
    break
# Out:
# Enter a question :Hello
# Hello! How can I help you today?
#
# Enter a question :Tell me virat kohli fullname
# Virat Kohli's full name is **Virat Kohli**.
#
# Enter a question :sample example of microservices using python
# ## Sample Microservices Example with Python (Flask)
#
# This example demonstrates a basic e-commerce system with three microservices:
#
# * **Product Service:** Manages product information (CRUD operations).
# * **Cart Service:** Manages user carts and items (CRUD operations).
# * **Order Service:** Handles order creation and management.
#
# **Dependencies:**
#
# * Python 3.6+
# * Flask
# * Flask-RESTful
# * Redis (for shared data)
#
# **1. Product Service:**
#
# ```python
# from flask import Flask, jsonify
# from flask_restful import Api, Resource, reqparse
#
# app = Flask(__name__)
# api = Api(app)
#
# # Define product model (simplified)
# class Product:
#     def __init__(self, id, name, price):
#         self.id = id
#         self.name = name
# ...
